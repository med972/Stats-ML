# %% [markdown]
# # Metric Learning with Stochastic Gradient Descent

# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import decomposition
from sklearn import metrics
import itertools

# %% [markdown]
# ## Loading and visualizing data

# %%
if 1:  # use iris
    iris = datasets.load_iris()
    X = iris.data
    y = iris.target
else:  # use digits
    digits = datasets.load_digits()
    X = digits.data
    y = digits.target

    # on ne garde que les 7 premieres classes par simplicite
    X = X[y < 7]
    y = y[y < 7]

# standardize data
X -= X.mean(axis=0)
X /= X.std(axis=0)
X[np.isnan(X)] = 0.


def plot_2d(X, y):
    """ Plot in 2D the dataset data, colors and symbols according to the
    class given by the vector y (if given); the separating hyperplan w can
    also be displayed if asked"""
    plt.figure()
    symlist = ['o', 's', '*', 'x', 'D', '+', 'p', 'v', 'H', '^']
    collist = ['blue', 'red', 'purple', 'orange', 'salmon', 'black', 'grey',
               'fuchsia']

    labs = np.unique(y)
    idxbyclass = [y == labs[i] for i in range(len(labs))]

    for i in range(len(labs)):
        plt.plot(X[idxbyclass[i], 0], X[idxbyclass[i], 1], '+',
                 color=collist[i % len(collist)], ls='None',
                 marker=symlist[i % len(symlist)])
    plt.ylim([np.min(X[:, 1]), np.max(X[:, 1])])
    plt.xlim([np.min(X[:, 0]), np.max(X[:, 0])])
    plt.show()

# %%
# on utilise PCA pour projeter les donnees en 2D
pca = decomposition.PCA(n_components=2)
X_2D = pca.fit_transform(X)
plot_2d(X_2D, y)

# %% [markdown]
# ## Approche basée sur les paires

# %% [markdown]
# ### Question 1

# %% [markdown]
# Deux cas de configuration  :
#
#         -si yi=yj (points xi & xj similaires, yij=1), l(dm^2,yij) = max(0,dm^2-1). Pour avoir un cout minimum il faut que dm^2<1 => dm < 1, logique on veut une petite distance
#         - si yi!=yj (points xi & xj non similaires, yij=-1), l(dm^2, yij) = max(0,3-dm^2). Pour avoir un cout minimum il faut que dm^2 > 3 => dm > (3)^1/2, logique on cherche à avoir une distance plus grande on la pénalise si elle est en dessus de certains seuil

# %% [markdown]
# ### Question 2

# %% [markdown]
# Compléter la fonction `sgd_metric_learning_pairs`. Vous n'avez qu'à ajouter le calcul du sous-gradient de la perte sur la paire tirée aléatoirement.

# %%
def psd_proj(M):
    """ projection de la matrice M sur le cone des matrices semi-definies
    positives"""
    # calcule des valeurs et vecteurs propres
    eigenval, eigenvec = np.linalg.eigh(M)
    # on trouve les valeurs propres negatives ou tres proches de 0
    ind_pos = eigenval > 1e-10
    # on reconstruit la matrice en ignorant ces dernieres
    M = np.dot(eigenvec[:, ind_pos] * eigenval[ind_pos][np.newaxis, :],
               eigenvec[:, ind_pos].T)
    return M


def hinge_loss_pairs(X, pairs_idx, y_pairs, M):
    """Calcul du hinge loss sur les paires
    """
    diff = X[pairs_idx[:, 0], :] - X[pairs_idx[:, 1], :]
    return np.maximum(0., 1. + y_pairs.T * (np.sum(np.dot(M, diff.T) * diff.T,
                                                   axis=0) - 2.))


def sgd_metric_learning_pairs(X, y, gamma, alpha, n_iter, n_eval, M_ini,
                              random_state=42, mini_batch=1):
    """Stochastic gradient algorithm for metric learning with pairs

    Parameters
    ----------
    X : array, shape (n_samples, n_features)
        The data
    y : array, shape (n_samples,)
        The targets.
    gamma : float | callable
        The step size. Can be a constant float or a function
        that allows to have a variable step size
    alpha : float
        The regularization parameter
    n_iter : int
        The number of iterations
    n_eval : int
        The number of pairs to evaluate the objective function
    M_ini : array, shape (n_features,n_features)
        The initial value of M
    random_state : int
        Random seed to make the algorithm deterministic
    """
    rng = np.random.RandomState(random_state)
    n_samples, n_features = X.shape

    # tirer n_eval paires aleatoirement
    # attention: celles-ci sont seulement utilisees pour evaluer la fonction objective
    pairs_idx = rng.randint(0, n_samples, (n_eval, 2))
    # calcul du label des paires d'evaluation
    y_pairs = 2.0 * (y[pairs_idx[:, 0]] == y[pairs_idx[:, 1]]) - 1.0
    M = M_ini.copy()
    pobj = np.zeros(n_iter)

    if not callable(gamma):
        def gamma_func(t):
            return gamma
    else:
        gamma_func = gamma

    for t in range(n_iter):
        # compute loss mean for a subpart of pairs (with regularization term)
        pobj[t] = np.mean(hinge_loss_pairs(X, pairs_idx, y_pairs, M)) + alpha*np.trace(M)
        gradient = np.zeros((n_features, n_features))

        # on tire 1 paire
        pair_for_gradient = rng.randint(0, n_samples, (mini_batch,2))
        
        # TODO QUESTION 2
        diff = X[pair_for_gradient[:, 0], :] - X[pair_for_gradient[:, 1], :]
        
        #1 si même label -1 sinon
        y_i_j = 2.0 * (y[pair_for_gradient[:, 0]] == y[pair_for_gradient[:, 1]]) - 1.0
        
        #compute cost and cost mask
        # !! pour la distance <=> une distance euclidienne avec auparavant une projection via un produit matriciel
        cost = 1. + y_i_j.T * (np.sum(np.dot(M, diff.T) * diff.T,axis=0) - 2.)
        
        for i in range(0,mini_batch) :
            #pour chaque pairs tirée j'ajoute le gradient associé
            #derivée de la tr(M) est la fonction identité
            if cost[i]>0:
                gradient += np.outer(diff[i],diff[i].T)*y_i_j[i]
            gradient += alpha * np.eye(M.shape[0])
        
        #moyenne mes gradients
        gradient = gradient / mini_batch
                
        M -= gamma_func(t) * gradient
        M = psd_proj(M) #projette le gradient dans l'espace des contraintes
        
    return M, pobj

# %%
np.trace(np.eye(3))
# Out:
# 3.0

# %% [markdown]
# ### Question 3

# %% [markdown]
# Tester l'algorithme sur Iris et Digits en adaptant le pas et le nombre d'itérations afin de le faire converger.

# %%
#test iris
n_features = X.shape[1]

M_ini = np.eye(n_features)
M, pobj = sgd_metric_learning_pairs(X, y, 0.002, 0.0, 20000, 1000, M_ini)

plt.figure()
plt.plot(pobj)
plt.xlabel('t')
plt.ylabel('cost')
plt.title('hinge stochastic with pairs')
plt.show()

e, v = np.linalg.eig(M)
print("Nb de valeurs propres de M égales à 0: ", np.sum(e < 1e-12), "/", e.shape[0])
# Out:
# Nb de valeurs propres de M égales à 0:  0 / 4

# %% [markdown]
# ### Question 4

# %% [markdown]
# Utiliser le code ci-dessous plus transformer les données et comparer visuellement les représentations en dimension 2.

# %%
# calcul de la factorisation de cholesky
# on ajoute de tres faibles coefficients sur la diagonale pour eviter
# les erreurs numeriques
L = np.linalg.cholesky(M + 1e-10 * np.eye(n_features))

# on projette lineairement les donnees dans l'espace déduit de M
X_proj = np.dot(X, L)

# TODO QUESTION 4: projeter X_proj en 2D avec une PCA
pca = decomposition.PCA(n_components=2)
X_proj_2D = pca.fit_transform(X_proj)
plot_2d(X_proj_2D, y)

# %% [markdown]
# Apprendre un metric <=> apprendre une projection des données dans un espace dans lequel la distance euclidienne traduit la notion de similarité voulue
#
#
# Ici on projette nos données dans l'espace appris à la question précédente : espace tel qu'on est la distance euclidienne entre des points de même classe inférieure à 1 entre des points de classes différentes >(3)^(1/2).
#
#
# Une fois les données projetées dans cette espace de dimension 4 ?, on effectue une réduction dimensionnelle via une PCA des données projetées dans ce nouvel espace.
# Cela montre que même avec la perte d'information impliquée par une réduction dimensionnelle  on peut observer que la séparation entre points de différentes classes (carré et étoile) est nette.

# %% [markdown]
# ### Question 5

# %% [markdown]
# Pour un échantillon aléatoire de paires d’apprentissage, calculer les valeurs de distance et comparer la courbe ROC de la distance apprise avec celle de la distance Euclidienne. Calculer également l’aire sous la courbe ROC (AUC).

# %%
def distances_random_pairs(X, y, M, n_pairs=10000, random_state=42):
    """Draw random pairs and compute their Euclidean and Mahalanobis distance

    Parameters
    ----------
    X : array, shape (n_samples, n_features)
        The data
    y : array, shape (n_samples,)
        The labels.
    M : array, shape (n_features, n_features)
        The matrix parameter of the Mahalanobis distance.
    n_pairs : int
        The number of pairs to sample
    random_state : int
        Random seed to make the algorithm deterministic
    """
    rng = np.random.RandomState(random_state)
    n_samples = X.shape[0]
    pairs = rng.randint(0, n_samples, (n_pairs, 2)) # tirer n_pairs paires aleatoires
    y_pairs = 2.0 * (y[pairs[:, 0]] == y[pairs[:, 1]]) - 1.0
    diff = X[pairs[:, 0], :] - X[pairs[:, 1], :]
    dist_euc = np.sqrt(np.sum(diff ** 2, axis=1)) #distance euclidienne entre mes pairs
    dist_M = np.sum(np.dot(M, diff.T) * diff.T, axis=0) #distance selon le metric appris
    return y_pairs, dist_euc, dist_M

# %%
# on tire 10000 paires aleatoires et on calcule les distances
y_pairs, dist_euc, dist_M = distances_random_pairs(X, y, M, n_pairs=10000)

# tracer les courbes ROC
from sklearn.metrics import roc_curve, auc
# TODO QUESTION 5
#compute y_predit sur distance euclidienne
fpr_euc, tpr_euc, thresholds = roc_curve(y_pairs,-dist_euc)
fpr_M, tpr_M, thresholds = roc_curve(y_pairs,-dist_M)

auc_euc = auc(fpr_euc, tpr_euc)
auc_M = auc(fpr_M, tpr_M)

#plot ROC curves

plt.figure()
plt.plot(fpr_euc, tpr_euc, label='Euclidean distance - AUC %.2f' % auc_euc)
plt.plot(fpr_M, tpr_M, label='Learnt distance - AUC %.2f' % auc_M)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# A la fonction roc curve on donne en entrée des true_labels (le ground truth) et les scores associés à chacun de ces labels selon un certain métric. Elle renvoie pour différents thresholds le taux de faux positif et true positive obtenu.
#
# Ensuite on peut tracer la courbe auc  via auc de scikit learn en mettant en entrée les taux de fpr et tpr obtenu aux différents threasholds. On peut ainsi choisi le threshold optimal à notre application en fonction du taux de faux positifs et true positifs voulu.
#
# Possibilité d'interpréter l'ordre sur la courbe roc comme la probabilité d'avoir scores négatifs plus grand que positifs

# %% [markdown]
# ### Question 6

# %% [markdown]
# Modifier la fonction `sgd_metric_learning_pairs` pour permettre une version mini-batch de l'algorithme. Explorer l'effet sur la convergence de l'algorithme.

# %%
#test iris

n_features = X.shape[1]

M_ini = np.eye(n_features)
M, pobj = sgd_metric_learning_pairs(X, y, 0.002, 0.0, 20000, 1000, M_ini, mini_batch=20)

plt.figure()
plt.plot(pobj)
plt.xlabel('t')
plt.ylabel('cost')
plt.title('hinge stochastic with pairs')
plt.show()

e, v = np.linalg.eig(M)
print("Nb de valeurs propres de M égales à 0: ", np.sum(e < 1e-12), "/", e.shape[0])
# Out:
# Nb de valeurs propres de M égales à 0:  0 / 4

# %%
#  AIDE POUR LE BONUS DE LA QUESTION 6:

# def combs(a, r):
#     """ compute all r-length combinations of elements in array; a faster
#     than np.array(list(itertools.combinations(a, r)))
#     """
#     a = np.asarray(a)
#     dt = np.dtype([('', a.dtype)] * r)
#     b = np.fromiter(itertools.combinations(a, r), dt)
#     return b.view(a.dtype).reshape(-1, r)

# %% [markdown]
# ### Question 7

# %% [markdown]
# Modifier la fonction `sgd_metric_learning_pairs` pour permettre une régularisation par la norme trace. Explorer le compromis entre performance et réduction de dimension.

# %%
#test iris

n_features = X.shape[1]

M_ini = np.eye(n_features)
M, pobj = sgd_metric_learning_pairs(X, y, 0.002, 0.1, 20000, 1000, M_ini, mini_batch=20)

plt.figure()
plt.plot(pobj)
plt.xlabel('t')
plt.ylabel('cost')
plt.title('hinge stochastic with pairs')
plt.show()

e, v = np.linalg.eig(M)
print("Nb de valeurs propres de M égales à 0: ", np.sum(e < 1e-12), "/", e.shape[0])
# Out:
# Nb de valeurs propres de M égales à 0:  2 / 4

# %%
# on tire 10000 paires aleatoires et on calcule les distances
y_pairs, dist_euc, dist_M = distances_random_pairs(X, y, M, n_pairs=10000)

# tracer les courbes ROC
from sklearn.metrics import roc_curve, auc
# TODO QUESTION 5
#compute y_predit sur distance euclidienne
fpr_euc, tpr_euc, thresholds = roc_curve(y_pairs,-dist_euc)
fpr_M, tpr_M, thresholds = roc_curve(y_pairs,-dist_M)

auc_euc = auc(fpr_euc, tpr_euc)
auc_M = auc(fpr_M, tpr_M)

#plot ROC curves

plt.figure()
plt.plot(fpr_euc, tpr_euc, label='Euclidean distance - AUC %.2f' % auc_euc)
plt.plot(fpr_M, tpr_M, label='Learnt distance - AUC %.2f' % auc_M)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Approche basée sur les triplets

# %% [markdown]
# ### Question 8

# %% [markdown]
# Donner ici l'interprétation de la fonction de perte.

# %% [markdown]
# L'objectif de cette fonction perte est d'avoir une distance entre deux points non similaires plus grande qu'une distance entre deux points similaires avec une marge (ici à 1, changer la marge revient à changer d'échelle).
#
#
# Pourquoi obtient-on une meilleure courbe ROC ?
# La courbe ROC s'interesse au taux de vrais positifs et faux positifs selon un score et un threshold. Pour avoir une aire maximale sous la courbe ROC il faut que les petits scores correspondent aux labels négatifs, les grands scores aux labels positifs, donc c'est l'ordre ntre les scores de deux labels différents qui compte.
#
#
# Dans l'approche pair on s'assure d'un côté que la distance entre points similaires est petite sinon on pénalise, de l'autre que la distance entre points non similaires est grande sinon on pénalise, ainsi indirectement on agit sur l'ordre des scores selon le label similaire/non-similaire. Alors que dans l'approche triplet on s'intéresse directement à cet ordre dans la fonction coût.

# %% [markdown]
# ### Question 9

# %% [markdown]
# Implémenter et expérimenter avec une version triplet de l'algorithme en complétant la fonction `sgd_metric_learning_triplets` ci-dessous. Vous n'avez qu'à ajouter le calcul du sous-gradient de la perte sur le triplet tiré aléatoirement.

# %%
def hinge_loss_triplets(X, triplets_idx, M):
    """Calcul du hinge loss sur les triplets
    """
    diffp = X[triplets_idx[:, 0], :] - X[triplets_idx[:, 1], :]
    diffn = X[triplets_idx[:, 0], :] - X[triplets_idx[:, 2], :]
    return np.maximum(0., 1. - np.sum(np.dot(M, diffn.T) * diffn.T, axis=0) +
                      np.sum(np.dot(M, diffp.T) * diffp.T, axis=0))


def generate_triplets(X, y, n_triplets, random_state=42):
    """Generation de triplets
    """
    rng = np.random.RandomState(random_state)
    n_samples = X.shape[0]
    triplets_idx = np.zeros((n_triplets, 3), dtype=int)
    triplets_idx[:, 0] = rng.randint(0, n_samples, (n_triplets,))
    for i in range(n_triplets):
        same_idx = np.where(y == y[triplets_idx[i, 0]])[0]
        diff_idx = np.where(y != y[triplets_idx[i, 0]])[0]
        triplets_idx[i, 1] = same_idx[rng.randint(0, same_idx.shape[0])]
        triplets_idx[i, 2] = diff_idx[rng.randint(0, diff_idx.shape[0])]
    return triplets_idx


def sgd_metric_learning_triplets(X, y, gamma, alpha, n_iter, n_eval, M_ini,
                                 random_state=42):
    """Stochastic gradient algorithm for metric learning with triplets

    Parameters
    ----------
    X : array, shape (n_samples, n_features)
        The data
    y : array, shape (n_samples,)
        The labels.
    gamma : float | callable
        The step size. Can be a constant float or a function
        that allows to have a variable step size
    alpha : float
        The regularization parameter
    n_iter : int
        The number of iterations
    n_eval : int
        The number of triplets to evaluate the objective function
    M_ini : array, shape (n_features,n_features)
        The initial value of M
    random_state : int
        Random seed to make the algorithm deterministic
    """
    rng = np.random.RandomState(random_state)
    n_samples, n_features = X.shape
    # generate n_eval triplets
    triplets_idx = generate_triplets(X, y, n_eval, random_state=random_state)
    M = M_ini.copy()
    pobj = np.zeros(n_iter)

    if not callable(gamma):
        def gamma_func(t):
            return gamma
    else:
        gamma_func = gamma

    for t in range(n_iter):
        pobj[t] = np.mean(hinge_loss_triplets(X, triplets_idx, M))
        gradient = np.zeros((n_features, n_features))

        # tirer 1 triplet
        triplet_for_gradient = generate_triplets(X, y, 1, random_state=random_state + t)[0]

        # TODO QUESTION 9
        diff_sim = (X[triplet_for_gradient[0], :] - X[triplet_for_gradient[1], :]).reshape(-1,1)
        diff_nosim = (X[triplet_for_gradient[0], :] - X[triplet_for_gradient[2], :]).reshape(-1,1)
        d_sim_2 = np.sum(np.dot(diff_sim.T,M) * diff_sim.T,axis=1)
        d_nosim_2 = np.sum(np.dot(diff_nosim.T,M) * diff_nosim.T,axis=1)
        cost = 1 + d_sim_2 - d_nosim_2
        
        if(cost>0):
            gradient = np.outer(diff_sim,diff_sim.T) - np.outer(diff_nosim,diff_nosim.T)

        M -= gamma_func(t) * gradient
        M = psd_proj(M)
    return M, pobj

# %%
#test iris
n_features = X.shape[1]

M_ini = np.eye(n_features)
M, pobj = sgd_metric_learning_triplets(X, y, 0.002, 0.0, 20000, 1000, M_ini)

plt.figure()
plt.plot(pobj)
plt.xlabel('t')
plt.ylabel('cost')
plt.title('hinge stochastic with pairs')
plt.show()

e, v = np.linalg.eig(M)
print("Nb de valeurs propres de M égales à 0: ", np.sum(e < 1e-12), "/", e.shape[0])
# Out:
# Nb de valeurs propres de M égales à 0:  0 / 4

# %%
# on tire 10000 paires aleatoires et on calcule les distances
y_pairs, dist_euc, dist_M = distances_random_pairs(X, y, M, n_pairs=10000)

# tracer les courbes ROC
from sklearn.metrics import roc_curve, auc
# TODO QUESTION 5
#compute y_predit sur distance euclidienne
fpr_euc, tpr_euc, thresholds = roc_curve(y_pairs,-dist_euc)
fpr_M, tpr_M, thresholds = roc_curve(y_pairs,-dist_M)

auc_euc = auc(fpr_euc, tpr_euc)
auc_M = auc(fpr_M, tpr_M)

#plot ROC curves

plt.figure()
plt.plot(fpr_euc, tpr_euc, label='Euclidean distance - AUC %.2f' % auc_euc)
plt.plot(fpr_M, tpr_M, label='Learnt distance - AUC %.2f' % auc_M)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# On constate effectivement une amélioration de l'AUC voir explications Q.8
